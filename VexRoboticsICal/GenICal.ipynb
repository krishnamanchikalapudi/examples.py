# %% [markdown]
# # Generate iCal format data from RobotEvents.com

# %%
pip install -U ipython-autotime ics pandas lxml requests
# Out:
# Looking in indexes: https://krishnam:****@psazuse.jfrog.io/artifactory/api/pypi/krishnam-pypi-virtual/simple
# ...
#   Using cached https://psazuse.jfrog.io/artifactory/api/pypi/krishnam-pypi-virtual/packages/packages/12/90/3c9ff0512038035f59d279fddeb79f5f1eccd8859f06d6163c58798b9487/certifi-2024.8.30-py3-none-any.whl (167 kB)
# ...
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext autotime
# Out:
# time: 58.8 μs (started: 2024-11-26 08:53:03 -08:00)

# %% [markdown]
# ## Parse HTML Content from Robot Events site

# %%
import pandas as pd
import ics as ics
# from ics import Calendar

print("Pandas Version: ", pd.__version__)
# Out:
# Pandas Version:  2.2.3
# time: 211 μs (started: 2024-11-26 08:53:05 -08:00)

# %%
robotics_url="https://robotevents.com/robot-competitions/vex-robotics-competition?country_id=244&country_region_id=12&event_tags%5B%5D=1&name=&grade_level_id=3&to_date=&event_region=3660&city=Dublin&distance=10"
# robotics_url="https://google.com"

# BEGIN: fix Python or Notebook SSL CERTIFICATE_VERIFY_FAILED
# import os, ssl
# if (not os.environ.get('PYTHONHTTPSVERIFY', '') and getattr(ssl, '_create_unverified_context', None)):
#     ssl._create_default_https_context = ssl._create_unverified_context
# END: fix Python or Notebook SSL CERTIFICATE_VERIFY_FAILED

import requests

resp = requests.get(robotics_url)
resp
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/krishnam/Documents/GitHub-KM/examples.py/VexRoboticsICal/GenICal.ipynb Cell 5 line 1
#       <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.py/VexRoboticsICal/GenICal.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> robotics_url="https://robotevents.com/robot-competitions/vex-robotics-competition?country_id=244&country_region_id=12&event_tags%5B%5D=1&name=&grade_level_id=3&to_date=&event_region=3660&city=Dublin&distance=10"
#       <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.py/VexRoboticsICal/GenICal.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> # robotics_url="https://google.com"
#       <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.py/VexRoboticsICal/GenICal.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a>
# ...

# %%
import requests as req

resp = req.get(robotics_url)
resp
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/krishnam/Documents/GitHub-KM/examples.py/VexRoboticsICal/GenICal.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.py/VexRoboticsICal/GenICal.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> import requests as req
#       <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.py/VexRoboticsICal/GenICal.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> resp = req.get(robotics_url)
#       <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.py/VexRoboticsICal/GenICal.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> resp
#
# File /opt/homebrew/lib/python3.11/site-packages/requests/__init__.py:151
#     148 import logging
#     149 from logging import NullHandler
# --> 151 from . import packages, utils
#     152 from .__version__ import (
#     153     __author__,
# ...
