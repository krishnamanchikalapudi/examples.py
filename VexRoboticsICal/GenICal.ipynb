# %% [markdown]
# # Generate iCal format data from RobotEvents.com

# %%
pip install ics pandas lxml
# Out:
# Looking in indexes: https://krishnam:****@psazuse.jfrog.io/artifactory/api/pypi/krishnam-pypi-virtual/simple
# Requirement already satisfied: ics in /opt/homebrew/lib/python3.11/site-packages (0.7.2)
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (2.2.3)
# Collecting lxml
#   Downloading https://psazuse.jfrog.io/artifactory/api/pypi/krishnam-pypi-virtual/packages/packages/5c/a8/449faa2a3cbe6a99f8d38dcd51a3ee8844c17862841a6f769ea7c2a9cd0f/lxml-5.3.0-cp311-cp311-macosx_10_9_universal2.whl (8.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 6.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: python-dateutil in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ics) (2.9.0.post0)
# Requirement already satisfied: arrow>=0.11 in /opt/homebrew/lib/python3.11/site-packages (from ics) (1.3.0)
# Requirement already satisfied: six>1.5 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ics) (1.16.0)
# Requirement already satisfied: tatsu>4.2 in /opt/homebrew/lib/python3.11/site-packages (from ics) (5.12.2)
# Requirement already satisfied: attrs>=19.1.0 in /opt/homebrew/lib/python3.11/site-packages (from ics) (24.2.0)
# Requirement already satisfied: numpy>=1.23.2 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/homebrew/lib/python3.11/site-packages (from arrow>=0.11->ics) (2.9.0.20241003)
# Installing collected packages: lxml
# Successfully installed lxml-5.3.0
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Parse HTML Content from Robot Events site

# %%
import urllib.request
import pandas as pd
import ics as ics
# from ics import Calendar

print("Pandas Version: ", pd.__version__)
# Out:
# Pandas Version:  2.2.3

# %%
# robotics_url="https://robotevents.com/robot-competitions/vex-robotics-competition?country_id=244&country_region_id=12&event_tags%5B%5D=1&name=&grade_level_id=3&to_date=&event_region=3660&city=Dublin&distance=10"
robotics_url="https://robotevents.com/robot-competitions/vex-robotics-competition\?country_id\=244\&country_region_id\=12\&event_tags%5B%5D\=1\&name\=\&grade_level_id\=3\&to_date\=\&event_region\=3660\&city\=Dublin\&distance\=10"
# robotics_url="https://google.com"

# BEGIN: fix Python or Notebook SSL CERTIFICATE_VERIFY_FAILED
import ssl
if (not os.environ.get('PYTHONHTTPSVERIFY', '') and getattr(ssl, '_create_unverified_context', None)):
    ssl._create_default_https_context = ssl._create_unverified_context
# END: fix Python or Notebook SSL CERTIFICATE_VERIFY_FAILED


f = urllib.request.urlopen(robotics_url, timeout=60)
myfile = f.read()
print(myfile)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /Users/krishnam/Documents/GitHub-KM/examples.py/VexRoboticsICal/GenICal.ipynb Cell 5 line 1
#       <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.py/VexRoboticsICal/GenICal.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a>     ssl._create_default_https_context = ssl._create_unverified_context
#       <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.py/VexRoboticsICal/GenICal.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a> # END: fix Python or Notebook SSL CERTIFICATE_VERIFY_FAILED
# ---> <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.py/VexRoboticsICal/GenICal.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a> f = urllib.request.urlopen(robotics_url, timeout=60)
#      <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.py/VexRoboticsICal/GenICal.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a> myfile = f.read()
#      <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.py/VexRoboticsICal/GenICal.ipynb#W2sZmlsZQ%3D%3D?line=13'>14</a> print(myfile)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.10/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.10/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File /opt/homebrew/Cellar/python@3.11/3.11.10/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File /opt/homebrew/Cellar/python@3.11/3.11.10/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.10/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /opt/homebrew/Cellar/python@3.11/3.11.10/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden
